# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix

# Load the dataset
bnotes = pd.read_csv('bank.csv')

# Define features and target variable
X = bnotes.drop('class', axis=1)  
y = bnotes['class']

# Function to train and evaluate the model
def train_and_evaluate(X, y, test_size):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    for activation in ['relu', 'logistic', 'tanh', 'identity']:
        print(f"\nTraining MLPClassifier with activation function: {activation} (Train-Test Ratio: {1 - test_size})")
        mlp = MLPClassifier(max_iter=500, activation=activation)
        mlp.fit(X_train, y_train)
        pred = mlp.predict(X_test)
        print("Confusion Matrix:")
        print(confusion_matrix(y_test, pred))
        print("\nClassification Report:")
        print(classification_report(y_test, pred))

# Train and evaluate with 20% test size
train_and_evaluate(X, y, test_size=0.2)

# Train and evaluate with 30% test size
train_and_evaluate(X, y, test_size=0.3)
# Out:
# Training MLPClassifier with activation function: relu (Train-Test Ratio: 0.8)
# Confusion Matrix:
# [[151   0]
#  [  0 124]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       151
#            1       1.00      1.00      1.00       124
#
#     accuracy                           1.00       275
#    macro avg       1.00      1.00      1.00       275
# weighted avg       1.00      1.00      1.00       275
#
#
# Training MLPClassifier with activation function: logistic (Train-Test Ratio: 0.8)
# Confusion Matrix:
# [[151   0]
#  [  0 124]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       151
#            1       1.00      1.00      1.00       124
#
#     accuracy                           1.00       275
#    macro avg       1.00      1.00      1.00       275
# weighted avg       1.00      1.00      1.00       275
#
#
# Training MLPClassifier with activation function: tanh (Train-Test Ratio: 0.8)
# Confusion Matrix:
# [[151   0]
#  [  0 124]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       151
#            1       1.00      1.00      1.00       124
#
#     accuracy                           1.00       275
#    macro avg       1.00      1.00      1.00       275
# weighted avg       1.00      1.00      1.00       275
#
#
# Training MLPClassifier with activation function: identity (Train-Test Ratio: 0.8)
# Confusion Matrix:
# [[150   1]
#  [  1 123]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       151
#            1       0.99      0.99      0.99       124
#
#     accuracy                           0.99       275
#    macro avg       0.99      0.99      0.99       275
# weighted avg       0.99      0.99      0.99       275
#
#
# Training MLPClassifier with activation function: relu (Train-Test Ratio: 0.7)
# Confusion Matrix:
# [[232   0]
#  [  0 180]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       232
#            1       1.00      1.00      1.00       180
#
#     accuracy                           1.00       412
#    macro avg       1.00      1.00      1.00       412
# weighted avg       1.00      1.00      1.00       412
#
#
# Training MLPClassifier with activation function: logistic (Train-Test Ratio: 0.7)
# Confusion Matrix:
# [[232   0]
#  [  1 179]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       232
#            1       1.00      0.99      1.00       180
#
#     accuracy                           1.00       412
#    macro avg       1.00      1.00      1.00       412
# weighted avg       1.00      1.00      1.00       412
#
#
# Training MLPClassifier with activation function: tanh (Train-Test Ratio: 0.7)
# Confusion Matrix:
# [[232   0]
#  [  1 179]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       232
#            1       1.00      0.99      1.00       180
#
#     accuracy                           1.00       412
#    macro avg       1.00      1.00      1.00       412
# weighted avg       1.00      1.00      1.00       412
#
#
# Training MLPClassifier with activation function: identity (Train-Test Ratio: 0.7)
# Confusion Matrix:
# [[229   3]
#  [  3 177]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       232
#            1       0.98      0.98      0.98       180
#
#     accuracy                           0.99       412
#    macro avg       0.99      0.99      0.99       412
# weighted avg       0.99      0.99      0.99       412
